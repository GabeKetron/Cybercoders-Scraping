# %%
import requests
import requests_cache
import numpy as np
import pandas as pd
import lxml.html as lxl
import nltk
import re
from nltk.corpus import stopwords
from datetime import datetime

# %%
requests_cache.install_cache('demo_cache')

# %%
def urls_scraping(base_url, search_term, pages, location=''):
    urls = []
    
    for page in range(pages):
        try:
            response = requests.get(base_url, params={'searchterms': search_term,
                                                      'searchlocation': location,
                                                      'page': page+1})
            response.raise_for_status()
        except:
            break
    
        root = lxl.fromstring(response.content)
        url = ['https://www.cybercoders.com' + link for link in root.xpath('//div[@class="job-title"]/a/@href')]
        urls += url
    
    return urls
    
    
def page_scraping(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
    except:
        return
    
    root = lxl.fromstring(response.content)
    # extract title
    title = root.xpath('//div[@class="job-title"]/h1/text()')[0].strip()     
    
    # extract city and location of that posting.
    location = [i.strip() for i in root.xpath('//div[@class="location"]/span/text()')[0].split(',')]
    city = location[0]
    state = location[1]
    
    # extract job type and salary(to be done)
    try:
        salary = [int(i.replace('k', '000')) for i in re.findall(r'\d+k',root.xpath('//div[@class="wage"]/span/text()')[0] ) ] 
        if salary == []:
            salary_lower = 'NA'
            salary_upper = 'NA'
        else:
            salary_lower = salary[0]
            salary_upper = salary[1]
    except:
        salary_lower = 'Glitch'
        salary_upper = 'Glitch'
    # extract preferred skills(string type)
    skill_ls = root.xpath('//div[@class="skills"]/ul[@class="skill-list"]                         \
           /li[@class="skill-item"]/a/span[@class="skill-name"]/text()')
    preferred_skill = ', '.join([skill.strip() for skill in skill_ls])
    
    # extract 'what you need for this position'
    need_for_position = root.xpath('//div[@class="section-data section-data-title" and @data-section="7"]/text()')
    need_for_position = ' '.join(need_for_position)
    #extract job id
    job_id = root.xpath('//div[@class="job-id"]/text()')[0].strip()
    job_id = re.sub('.*: ','', job_id)  
    
    #extract post date
    post_date = root.xpath('//div[@class="mobile-hide posted-today posted-text" \
    or @class= "mobile-hide posted posted-text"]/span/text()')[0].strip()
 
    
    if post_date == 'Posted Today':
        post_date = datetime.today().strftime('%m/%d/%Y')
    else:
        post_date = re.sub(r'^Posted ([0-9]{2}/[0-9]{2}/[0-9]{4})', r'\1', post_date)
    
    return pd.Series({'city':city, 'state': state, 'salary_lower': salary_lower, 'salary_upper': salary_upper, 'preferred_skill':preferred_skill, 'need_for_position': need_for_position,
           'job_id': job_id, 'post_date': post_date})

def scraping(base_url, search_term, pages, location=''):
    urls = urls_scraping(base_url, search_term, pages, location='')
    scraping_data = [page_scraping(link) for link in urls]
    #scraping_data = []
    #for link in urls:
    #    print link
    #    scraping_data.append(page_scraping(link))
    return pd.concat(scraping_data, axis=1).T

# %%
Software_Engineer = scraping('https://www.cybercoders.com/search/', 'Software Engineer', 6)

# %%
Software_Engineer.head()
Software_Engineer.to_csv('Software_EngineerTest.csv',encoding="utf-8")

# %% [markdown]
# Just for debugging

# %%
response = requests.get('https://www.cybercoders.com/data-scientist-job-267769')
response.raise_for_status()
root = lxl.fromstring(response.content)

# %%
root.xpath('//div[@class="mobile-hide posted-today posted-text"]/span/text()')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [13], in <module>
# ----> 1 root.xpath('//div[@class="mobile-hide posted-today posted-text"]/span/text()')[0]
#
# IndexError: list index out of range

# %%
a = root.xpath('//div[@class="mobile-hide posted-today posted-text" or @class= "mobile-hide posted posted-text"]/span/text()')[0].strip()

# %%
a

# %%
#pd.concat([pd.Series(a), pd.Series(b), pd.Series(a)], axis=1).T
#urls_scraping(base_url, search_term, pages, location='')
Software_Engineer.head(40)
# Out:
#                city             state salary_lower salary_upper  \
# 0         Ann Arbor      MI • Houston       110000       180000
# 1     San Francisco    CA • Palo Alto       140000       190000
# 2           Seattle     WA • New York       180000       225000
# 3            Boston                MA       100000       140000
# 4     Santa Barbara                CA       100000       130000
# 5         Lone Tree                CO       120000       175000
# 6            Orange                CA       160000       200000
# 7          San Jose                CA       160000       200000
# 8     San Francisco                CA       160000       200000
# 9           Bozeman                MT       110000       130000
# 10          Bozeman                MT       110000       130000
# 11            Plano                TX       100000       120000
# 12            Plano                TX        75000       120000
# 13          Raleigh                NC       100000       150000
# 14       Fort Worth                TX       110000       130000
# 15           Sharon                MA       120000       130000
# 16           Durham                NC       120000       150000
# 17          Laramie                WY        80000       140000
# 18      Los Angeles     CA • Portland       110000       150000
# 19  Fort Lauderdale                FL       100000       130000
# 20       Washington  DC • San Antonio       130000       200000
# 21        Montville     NJ • New York       100000       130000
# 22    San Francisco                CA       180000       225000
# 23        Annandale      VA • Seattle       110000       180000
# 24           Dayton                OH        80000       100000
# 25         Columbia                MD       120000       180000
# 26          Phoenix                AZ       120000       160000
# 27        Cambridge                MA       130000       190000
# 28          Atlanta                GA       100000       130000
# 29        San Diego                CA       120000       180000
# 30    San Francisco                CA       150000       225000
# 31            Miami                FL       190000       200000
# 32     Santa Monica                CA       140000       170000
# 33          Raleigh                NC       130000       160000
# 34         New York                NY       120000       170000
# 35            Miami                FL        55000       160000
# 36         Hartford                CT        85000       100000
# 37            Boise                ID       150000       225000
# 38        St. Louis                MO       150000       225000
# 39         Portland                OR       150000       225000
#
#                                       preferred_skill  \
# 0   .NET, C#, REACT, React.JS, Angular.js, Senior ...
# 1   React.JS, Node.js, Senior Software Engineer, S...
# 2   Ruby On Rails, ROR, REACT, Senior Software Dev...
# 3             Software Engineer, Ruby On Rails, REACT
# 4             Software Engineer, Ruby On Rails, REACT
# 5                          Software Engineer, C++, C#
# 6   C++, Java, TCP/IP, Cisco, securex, ForeScout, ...
# 7   C++, Java, TCP/IP, Cisco, securex, ForeScout, ...
# 8   C++, Java, TCP/IP, Cisco, securex, ForeScout, ...
# 9            Devops, Engineer, Software, Technologies
# 10           Devops, Engineer, Software, Technologies
# 11  C++, Scripting, BAT, Python, Shell, Groovy, Ja...
# 12  C, C++, Golang, TypeScript, NodeJS, Product De...
# 13  Software Engineer, C++, Matlab, Python, SimuLi...
# 14  Software Engineer, Software Development, JavaS...
# 15  Software Engineer, Workflow processes, Workflo...
# 16  Software Engineer, C++, Matlab, Python, SimuLi...
# 17  Software Engineer, GUI Interfaces, Linux, C++,...
# 18  Node.js, node engineer, REACT, React Engineer,...
# 19        Engineer, C#, Linux, OpenWRT, WRT, open WRT
# 20               Engineer, C, C++, Linux, C#, C Sharp
# 21  C#, .NET Core, .NET, ASP.NET, Angular, SQL Ser...
# 22  Image Processing, OpenCL, SLAM, Software Engin...
# 23  C++, REACT, Node.js, Senior Software Engineer,...
# 24  ASP.NET, C#, SQL, JavaScript, Agile, Angular, ...
# 25  TS/SCI with Polygraph, Rest, Java, AWS, Kubert...
# 26  JavaScript, TypeScript, Test Driven Developmen...
# 27                   Python, Vue.js, Postgres, Django
# 28           Java, Spring, Rest, WildFly, Tomcat, API
# 29  AWS, Python, Lambda, DynamoDB, Aurora, API Gat...
# 30  REACT, JavaScript, TypeScript, CSS, React Nati...
# 31  Python, Docker, AWS, dev ops, Software Develop...
# 32  C#, Kafka, .NET Core, DynamoDB, CloudFormation...
# 33  JavaScript, TypeScript, Test Driven Developmen...
# 34                                 C#, .NET, SQL, API
# 35  dev ops, CI/CD, Kubernetes, Docker, Jenkins, T...
# 36                       SQL, ASP.NET, C#, SQL Server
# 37  REACT, JavaScript, TypeScript, CSS, React Nati...
# 38  REACT, JavaScript, TypeScript, CSS, React Nati...
# 39  REACT, JavaScript, TypeScript, CSS, React Nati...
#
#                                     need_for_position        job_id  \
# 0   - .NET - C# \n- REACT \n- React.JS \n- Angular...  AG17-1674760
# 1   - React.JS - Node.js \n- Senior Software Engin...  AG17-1674756
# 2   At least 10 years experience and B.S. in C.S. ...  AG17-1671934
# 3   - 3+ years developing software in commercial e...  LP10-1660041
# 4   - 3+ years developing software in commercial e...  LP10-1655928
# 5   - 3+ Years Experience as a Software Engineer -...  AM20-1667110
# 6   Required: -7+ Years of development experience ...   DF7-1672354
# 7   Required: -7+ Years of development experience ...   DF7-1672362
# 8   Required: -7+ Years of development experience ...   DF7-1672364
# 9   5-10+ years of experience  Strong interpersona...   VP5-1671111
# 10  5-10+ years of experience  Strong interpersona...   VP5-1672286
# 11  \n-Jenkins experience \n-Octopus experience \n...   SL5-1666071
# 12  - 2+ years of Software Engineering experience ...   SL5-1651186
# 13  REQUIRED: Secret Clearance, DoD Clearance, TS/...  AH13-1671093
# 14  Responsibilities: \n- Develops new functionali...   TH5-1664291
# 15  Bachelor's Degree in Computer Science or relat...    NG-1673470
# 16  REQUIRED: Secret Clearance, DoD Clearance, TS/...  AH13-1672221
# 17  - Software Engineer - GUI Interfaces \n- Linux...   KK7-1666809
# 18                                                     JC20-1672348
# 19               Required: - C# \n- Linux \n- OpenWRT  AM20-1664983
# 20  Required: - 3+ Years Exp. in Related Field \n-...  AM20-1672018
# 21  - Minimum of 3 years of experience working wit...  JD14-1669930
# 22  Must have knowledge or experience of the follo...   MO5-1668751
# 23  - C++ - REACT \n- Node.js \n- Senior Software ...  AG17-1674224
# 24  We're a great company to work for and we need ...   BW4-1488208
# 25  - TS/SCI with Polygraph \n2+ years experience ...  CC18-1623254
# 26  Required: \n- 7+ years developing software \n ...   ET3-1660075
# 27  - 5+ years of experience - Python \n- Vue.js \...  CC18-1661558
# 28  - Bachelor of Information Technology (IT) or C...   PT3-1661657
# 29  - 4+ years of experience  - AWS \n- Python \n-...  CC18-1662251
# 30  At least 3+ years experience with.. - React \n...   DQ2-1662398
# 31  3-5 Years of Experience with:  - Python \n- Do...  AR14-1665728
# 32  - 5+ years of experience in Software Developme...   CO3-1665870
# 33  Required: \n- 7+ years developing software \n ...  KC16-1656867
# 34  At least 7 years of experience with: - C# \n- ...   KT5-1665940
# 35  At least 3+ years experience with:  - HTML5 \n...   NI1-1666036
# 36  - 7+ years of programming experience working w...   RK3-1665587
# 37  At least 3+ years experience with.. - React \n...   DQ2-1662597
# 38  At least 3+ years experience with.. - React \n...   DQ2-1662598
# 39  At least 3+ years experience with.. - React \n...   DQ2-1662600
#
#      post_date
# 0   02/14/2022
# 1   02/14/2022
# 2   01/27/2022
# 3   12/07/2021
# 4   11/03/2021
# 5   12/21/2021
# 6   01/31/2022
# 7   02/04/2022
# 8   01/31/2022
# 9   01/29/2022
# 10  01/29/2022
# 11  01/20/2022
# 12  10/01/2021
# 13  01/27/2022
# 14  12/14/2021
# 15  02/04/2022
# 16  02/11/2022
# 17  12/17/2021
# 18  02/09/2022
# 19  02/09/2022
# 20  01/27/2022
# 21  02/02/2022
# 22  01/11/2022
# 23  02/09/2022
# 24  04/22/2020
# 25  11/30/2021
# 26  02/14/2022
# 27  02/11/2022
# 28  02/04/2022
# 29  11/18/2021
# 30  12/10/2021
# 31  12/13/2021
# 32  12/13/2021
# 33  02/14/2022
# 34  02/08/2022
# 35  12/14/2021
# 36  12/10/2021
# 37  12/10/2021
# 38  12/10/2021
# 39  12/10/2021
